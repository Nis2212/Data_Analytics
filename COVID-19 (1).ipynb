# %%
import numpy as np
import pandas as pd

# %%
covid_df = pd.read_csv("day_wise.csv")

# %%
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
covid_df
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
covid_df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB

# %%
covid_df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
covid_df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
covid_df.shape
# Out:
# (188, 12)

# %%
covid_df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
covid_data_dict = {
    'Date':     [ '2020-01-22', '2020-01-23','2020-01-24','2020-01-25','2020-01-26'],
    'new_cases':[ 0 ,99,287,493,684],
    'new_deaths':[0,1,8,16,14],
    'new_tests':[0,2,6,3,13] 
}

# %%
covid_data_dict['new_cases']
# Out:
# [0, 99, 287, 493, 684]

# %%
max_new_cases_row = covid_df.loc[covid_df["New cases"].idxmax()]

# %%
max_new_cases_row
# Out:
# Date                      2020-07-23
# Confirmed                   15510481
# Deaths                        633506
# Recovered                    8710969
# Active                       6166006
# New cases                     282756
# New deaths                      9966
# New recovered                 169714
# Deaths / 100 Cases              4.08
# Recovered / 100 Cases          56.16
# Deaths / 100 Recovered          7.27
# No. of countries                 187
# Name: 183, dtype: object

# %%
covid_df = covid_df[['Date','New cases']]
covid_df
# Out:
#            Date  New cases
# 0    2020-01-22          0
# 1    2020-01-23         99
# 2    2020-01-24        287
# 3    2020-01-25        493
# 4    2020-01-26        684
# ..          ...        ...
# 183  2020-07-23     282756
# 184  2020-07-24     281164
# 185  2020-07-25     255545
# 186  2020-07-26     204606
# 187  2020-07-27     228693
#
# [188 rows x 2 columns]

# %%
covid_df_copy = covid_df.copy()

# %%
covid_df_copy
# Out:
#            Date  New cases
# 0    2020-01-22          0
# 1    2020-01-23         99
# 2    2020-01-24        287
# 3    2020-01-25        493
# 4    2020-01-26        684
# ..          ...        ...
# 183  2020-07-23     282756
# 184  2020-07-24     281164
# 185  2020-07-25     255545
# 186  2020-07-26     204606
# 187  2020-07-27     228693
#
# [188 rows x 2 columns]

# %%
covid_df.loc[180]
# Out:
# Date         2020-07-20
# New cases        206778
# Name: 180, dtype: object

# %%
type(covid_df.loc[180])
# Out:
# pandas.core.series.Series

# %%
covid_df.tail(4)
# Out:
#            Date  New cases
# 184  2020-07-24     281164
# 185  2020-07-25     255545
# 186  2020-07-26     204606
# 187  2020-07-27     228693

# %%
covid_df.at[4,'New cases']
# Out:
# 684

# %%
covid_df.last_valid_index()
# Out:
# 187

# %%
covid_df.sample(10)
# Out:
#            Date  New cases
# 95   2020-04-26      72948
# 18   2020-02-09       3027
# 86   2020-04-17      87724
# 97   2020-04-28      75404
# 75   2020-04-06      72672
# 129  2020-05-30     137833
# 16   2020-02-07       3532
# 28   2020-02-19        421
# 30   2020-02-21        629
# 156  2020-06-26     191346

# %%
total_cases = covid_df["New cases"].sum()
print ("Total New Cases is ", total_cases )
# Out:
# Total New Cases is  16500952

# %%
import pandas as pd

# Read dataset
covid_df = pd.read_csv("day_wise.csv")

# Clean column names (in case of extra spaces)
covid_df.columns = covid_df.columns.str.strip()

# Ensure 'New deaths' column exists and is numeric
if "New deaths" in covid_df.columns:
    covid_df["New deaths"] = pd.to_numeric(covid_df["New deaths"], errors="coerce")  # Convert to numeric

# Calculate total deaths
total_deaths = covid_df["New deaths"].sum()

# Print result
print(f"Total Deaths: {total_deaths}")
# Out:
# Total Deaths: 654019

# %%
death_rate = covid_df["New deaths"].sum() / covid_df["New cases"].sum() *100
death_rate
# Out:
# 3.9635228318947897

# %%
death_rate1 = covid_df["New deaths"].sum()
death_rate1
# Out:
# 654019

# %%
new_cases =covid_df["New cases"].sum()
new_cases
# Out:
# 16500952

# %%
d_rate = death_rate1 / new_cases *100
d_rate
# Out:
# 3.9635228318947897

# %%
initial_test = 935310
total_test = initial_test + covid_df["New cases"].sum()
total_test
# Out:
# 17436262

# %%
high_new_cases = covid_df["New cases"] >1000
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 183     True
# 184     True
# 185     True
# 186     True
# 187     True
# Name: New cases, Length: 188, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 6    2020-01-28       5578     131        107     5340       2651          49
# 8    2020-01-30       8234     171        141     7922       2068          38
# 9    2020-01-31       9927     213        219     9495       1693          42
# 10   2020-02-01      12038     259        281    11498       2111          46
# 11   2020-02-02      16787     362        459    15966       4749         103
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
high_cases_df = covid_df[covid_df["New cases"] >1000]
high_cases_df
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 6    2020-01-28       5578     131        107     5340       2651          49
# 8    2020-01-30       8234     171        141     7922       2068          38
# 9    2020-01-31       9927     213        219     9495       1693          42
# 10   2020-02-01      12038     259        281    11498       2111          46
# 11   2020-02-02      16787     362        459    15966       4749         103
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
from IPython.display import display
import pandas as pd

# Read dataset
covid_df = pd.read_csv("day_wise.csv")

# Ensure 'New cases' column is numeric
covid_df["New cases"] = pd.to_numeric(covid_df["New cases"], errors="coerce")

# Display DataFrame with filtered rows where 'New cases' > 1000
with pd.option_context("display.max_rows", 100):
    display(covid_df[covid_df["New cases"] > 1000])
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 6    2020-01-28       5578     131        107     5340       2651          49
# 8    2020-01-30       8234     171        141     7922       2068          38
# 9    2020-01-31       9927     213        219     9495       1693          42
# 10   2020-02-01      12038     259        281    11498       2111          46
# 11   2020-02-02      16787     362        459    15966       4749         103
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
covid_df_sorted = covid_df.sort_values(by="New cases", ascending=False).head(10)
covid_df_sorted
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 182  2020-07-22   15227725  623540    8541255  6062930     280647        6983
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 176  2020-07-16   13812525  589760    7634241  5588524     252544        5799
# 177  2020-07-17   14054563  596503    7793760  5664300     242038        6743
# 178  2020-07-18   14292198  602130    7944550  5745518     237635        5627
# 181  2020-07-21   14947078  616557    8364986  5965535     233565        6238
# 170  2020-07-10   12505640  560142    6804254  5141244     232577        5311
# 175  2020-07-15   13559984  583961    7482320  5493703     231122        5493
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
covid_df.loc[169:175]
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 169  2020-07-09   12273063  554831    6665237  5052995     228227        5458
# 170  2020-07-10   12505640  560142    6804254  5141244     232577        5311
# 171  2020-07-11   12721968  565039    6929711  5227218     216328        4897
# 172  2020-07-12   12914636  568993    7041174  5304469     192668        3954
# 173  2020-07-13   13107415  572808    7181139  5353468     192779        3815
# 174  2020-07-14   13328867  578468    7322897  5427502     221452        5660
# 175  2020-07-15   13559984  583961    7482320  5493703     231122        5493
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 169         134221                4.52                  54.31
# 170         139017                4.48                  54.41
# 171         125457                4.44                  54.47
# 172         111463                4.41                  54.52
# ...

# %%
 covid_df.at[172,"New cases"] = (covid_df.at[171, "New cases"] +
                                 covid_df.at[172, "New cases"])/2
covid_df
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
covid_df.Date
# Out:
# 0      2020-01-22
# 1      2020-01-23
# 2      2020-01-24
# 3      2020-01-25
# 4      2020-01-26
#           ...
# 183    2020-07-23
# 184    2020-07-24
# 185    2020-07-25
# 186    2020-07-26
# 187    2020-07-27
# Name: Date, Length: 188, dtype: object

# %%
covid_df["Date"] = pd.to_datetime(covid_df["Date"], errors="coerce")
print(covid_df.head())
# Out:
#         Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0 2020-01-22        555      17         28     510          0           0
# 1 2020-01-23        654      18         30     606         99           1
# 2 2020-01-24        941      26         36     879        287           8
# 3 2020-01-25       1434      42         39    1353        493          16
# 4 2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
covid_df['Date']
# Out:
# 0     2020-01-22
# 1     2020-01-23
# 2     2020-01-24
# 3     2020-01-25
# 4     2020-01-26
#          ...
# 183   2020-07-23
# 184   2020-07-24
# 185   2020-07-25
# 186   2020-07-26
# 187   2020-07-27
# Name: Date, Length: 188, dtype: datetime64[ns]

# %% [markdown]
# ## Grouping and Aggregation

# %%
covid_df["Date"] = pd.to_datetime(covid_df["Date"], errors="coerce")

# Extract the year from the 'Date' column
covid_df["Year"] = covid_df["Date"].dt.year  # Correct way to extract year
covid_df["month"] = covid_df["Date"].dt.month
covid_df["day"] = covid_df["Date"].dt.day
covid_df["Weekday"] = covid_df["Date"].dt.weekday

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    datetime64[ns]
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
#  12  Year                    188 non-null    int32
#  13  month                   188 non-null    int32
# ...

# %%
covid_df.groupby('month')

# %%
covid_df_may= covid_df[covid_df.month ==5]

# %%
covid_df_may
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 100 2020-05-01    3355922  239881    1026501  2089540      87046        5177
# 101 2020-05-02    3437608  245206    1066362  2126040      81853        5325
# 102 2020-05-03    3515244  248659    1097577  2169008      77636        3453
# 103 2020-05-04    3591321  252787    1130526  2208008      76078        4128
# 104 2020-05-05    3671310  258658    1166155  2246497      79989        5871
# 105 2020-05-06    3761332  265327    1210894  2285111      90022        6669
# 106 2020-05-07    3850418  270736    1249311  2330371      90669        5409
# 107 2020-05-08    3941935  276304    1284849  2380782      92997        5568
# 108 2020-05-09    4027781  280569    1337367  2409845      85846        4265
# 109 2020-05-10    4104027  284135    1370108  2449784      76255        3566
# 110 2020-05-11    4180268  287608    1416204  2476456      76298        3473
# ...

# %%
covid_df_may_metric = covid_df_may[['New cases','New deaths']]

# %%
covid_df_may_metric = covid_df_may[['New cases','New deaths']]
covid_may_totals = covid_df_may_metric.sum()
covid_df_may_metric
# Out:
#      New cases  New deaths
# 100      87046        5177
# 101      81853        5325
# 102      77636        3453
# 103      76078        4128
# 104      79989        5871
# 105      90022        6669
# 106      90669        5409
# 107      92997        5568
# 108      85846        4265
# 109      76255        3566
# 110      76298        3473
# 111      83619        5547
# 112      84917        5228
# 113      97106        5268
# 114      96349        5215
# 115      95412        4171
# 116      78509        3329
# 117      88284        3291
# 118      96633        4784
# 119     103028        4885
# 120     106438        4786
# 121     106900        5284
# 122     105289        3989
# 123      95326        3140
# 124      87335        1178
# 125      92742        4203
# 126     102600        5213
# 127     119314        4701
# 128     121167        4742
# 129     137833        4156
# 130     107552        2888

# %%
covid_may_totals = covid_df_may_metric.sum()
covid_may_totals
# Out:
# New cases     2921042
# New deaths     138902
# dtype: int64

# %%
type(covid_may_totals)
# Out:
# pandas.core.series.Series

# %%
covid_df[covid_df.Weekday == 6]["New cases"].mean()
# Out:
# 82283.37037037036

# %%
covid_month_df = covid_df.groupby('month')[['New cases','New deaths']].sum()

# %%
covid_month_df
# Out:
#        New cases  New deaths
# month
# 1           9372         196
# 2          75379        2723
# 3         786064       41542
# 4        2412383      190226
# 5        2921042      138902
# 6        4265801      137604
# 7        6042741      142826

# %%
covid_df
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0   2020-01-22        555      17         28      510          0           0
# 1   2020-01-23        654      18         30      606         99           1
# 2   2020-01-24        941      26         36      879        287           8
# 3   2020-01-25       1434      42         39     1353        493          16
# 4   2020-01-26       2118      56         52     2010        684          14
# ..         ...        ...     ...        ...      ...        ...         ...
# 183 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
unique_months = covid_df["month"].unique()
unique_months
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int32)

# %%
covid_month_df = covid_df.groupby('month')[['New cases','New deaths']].sum()
covid_month_df
# Out:
#        New cases  New deaths
# month
# 1           9372         196
# 2          75379        2723
# 3         786064       41542
# 4        2412383      190226
# 5        2921042      138902
# 6        4265801      137604
# 7        6042741      142826

# %%
total_death = covid_df['New deaths'].sum()
total_death
# Out:
# 654019

# %%
total_new_cases = covid_df['New cases'].sum()
total_new_cases
# Out:
# 16512782

# %%
covid_df["New cases"] = pd.to_numeric(covid_df["New cases"], errors="coerce")
total_new_cases = covid_df["New cases"].sum()
covid_df["percentage_new_cases"] = (covid_df["New cases"] / total_new_cases) * 100
print(covid_df[["New cases", "percentage_new_cases"]])
# Out:
#             New cases  percentage_new_cases
# Date
# 2020-01-22          0              0.000000
# 2020-01-23         99              0.000600
# 2020-01-24        287              0.001738
# 2020-01-25        493              0.002986
# 2020-01-26        684              0.004142
# ...               ...                   ...
# 2020-07-23     282756              1.712346
# 2020-07-24     281164              1.702705
# 2020-07-25     255545              1.547559
# 2020-07-26     204606              1.239076
# 2020-07-27     228693              1.384945
#
# [188 rows x 2 columns]

# %%
print(covid_df.head())
# Out:
#         Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0 2020-01-22        555      17         28     510          0           0
# 1 2020-01-23        654      18         30     606         99           1
# 2 2020-01-24        941      26         36     879        287           8
# 3 2020-01-25       1434      42         39    1353        493          16
# 4 2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries  Year  month  day  Weekday  \
# 0                   60.71                 6  2020      1   22        2
# ...

# %%
covid_month_df = covid_df.groupby('month')[['New cases','New deaths','percentage_new_cases']].sum()
covid_month_df
# Out:
#        New cases  New deaths  percentage_new_cases
# month
# 1           9372         196              0.056756
# 2          75379        2723              0.456489
# 3         786064       41542              4.760337
# 4        2412383      190226             14.609186
# 5        2921042      138902             17.689581
# 6        4265801      137604             25.833327
# 7        6042741      142826             36.594324

# %%
covid_df['total_cases'] = covid_df["New cases"].cumsum()
covid_df
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0   2020-01-22        555      17         28      510          0           0
# 1   2020-01-23        654      18         30      606         99           1
# 2   2020-01-24        941      26         36      879        287           8
# 3   2020-01-25       1434      42         39     1353        493          16
# 4   2020-01-26       2118      56         52     2010        684          14
# ..         ...        ...     ...        ...      ...        ...         ...
# 183 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
location_df = pd.read_csv ("worldometer_data.csv")

# %%
location_df
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
location_df[location_df["Country/Region"] == "USA"]
# Out:
#   Country/Region      Continent   Population  TotalCases  NewCases  \
# 0            USA  North America  331198130.0     5032179       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
#
#    Tests/1M pop WHO Region
# 0      190640.0   Americas

# %%
covid_df["Country/Region"] = "USA"
covid_df
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0   2020-01-22        555      17         28      510          0           0
# 1   2020-01-23        654      18         30      606         99           1
# 2   2020-01-24        941      26         36      879        287           8
# 3   2020-01-25       1434      42         39     1353        493          16
# 4   2020-01-26       2118      56         52     2010        684          14
# ..         ...        ...     ...        ...      ...        ...         ...
# 183 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
merged_df = covid_df.merge(location_df, on = "Country/Region")
merged_df
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0   2020-01-22        555      17         28      510          0           0
# 1   2020-01-23        654      18         30      606         99           1
# 2   2020-01-24        941      26         36      879        287           8
# 3   2020-01-25       1434      42         39     1353        493          16
# 4   2020-01-26       2118      56         52     2010        684          14
# ..         ...        ...     ...        ...      ...        ...         ...
# 183 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    datetime64[ns]
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
#  12  Year                    188 non-null    int32
#  13  month                   188 non-null    int32
# ...

# %% [markdown]
# ## writing data back to files

# %%
result_df = merged_df [['Date',
                        'Confirmed',
                        'Deaths',
                        'Recovered',
                        'Active',
                        'New cases',
                        'New recovered',
                        'Deaths / 100 Cases',
                        'No. of countries',
                        'Year',
                        'month',
                        'day',
                        'Weekday',
                        'percentage_new_cases',
                        'total_cases',
                        'NewCases',
                        'TotalDeaths',
                        'TotalRecovered',
                        'ActiveCases',
                        'Serious,Critical']]

# %%
result_df
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  \
# 0   2020-01-22        555      17         28      510          0
# 1   2020-01-23        654      18         30      606         99
# 2   2020-01-24        941      26         36      879        287
# 3   2020-01-25       1434      42         39     1353        493
# 4   2020-01-26       2118      56         52     2010        684
# ..         ...        ...     ...        ...      ...        ...
# 183 2020-07-23   15510481  633506    8710969  6166006     282756
# 184 2020-07-24   15791645  639650    8939705  6212290     281164
# 185 2020-07-25   16047190  644517    9158743  6243930     255545
# 186 2020-07-26   16251796  648621    9293464  6309711     204606
# 187 2020-07-27   16480485  654036    9468087  6358362     228693
#
#      New recovered  Deaths / 100 Cases  No. of countries  Year  month  day  \
# 0                0                3.06                 6  2020      1   22
# ...

# %%
result_df.to_csv('results.csv', index = None)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plotting with pandas

# %%
covid_df["New cases"].plot();

# %%
covid_df["Date"] = pd.to_datetime(covid_df["Date"], errors="coerce")

# Set 'Date' as the index
covid_df.set_index("Date", inplace=True)

# Display the modified DataFrame
print(covid_df)
# Out:
#             Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Date
# 2020-01-22        555      17         28      510          0           0
# 2020-01-23        654      18         30      606         99           1
# 2020-01-24        941      26         36      879        287           8
# 2020-01-25       1434      42         39     1353        493          16
# 2020-01-26       2118      56         52     2010        684          14
# ...               ...     ...        ...      ...        ...         ...
# 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# ...

# %%
covid_df["New cases"].plot();

# %%
covid_df.loc['2020-01-22']
# Out:
# Confirmed                   555
# Deaths                       17
# Recovered                    28
# Active                      510
# New cases                     0
# New deaths                    0
# New recovered                 0
# Deaths / 100 Cases         3.06
# Recovered / 100 Cases      5.05
# Deaths / 100 Recovered    60.71
# No. of countries              6
# Year                       2020
# month                         1
# day                          22
# Weekday                       2
# percentage_new_cases        0.0
# total_cases                   0
# Country/Region              USA
# Name: 2020-01-22 00:00:00, dtype: object

# %%
covid_df["New cases"].plot()
covid_df["New deaths"].plot()
# Out:
# <Axes: xlabel='Date'>
